# %% [markdown]
# # Generate dataset of sample responses for each proficiency level.

# %%
import os

folder_path = "../data/guideline-descriptions"

files = os.listdir(folder_path)

guidelines = {}

for file_name in files:
    file_path = os.path.join(folder_path, file_name)
    
    # Check if the path is a file (not a directory)
    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            content = file.read()
            file_name_without_extension = os.path.splitext(file_name)[0]
            guidelines[file_name_without_extension] = content

# %%
import os

for key in guidelines:
    if not os.path.exists(f"../data/guideline-data/{key}"):
        os.makedirs(f"../data/guideline-data/{key}")

# %%
PROMPT = """
Your role is to generate a potential statement from a Spanish speaker that would be categorized as "{level}".

Here is the description for "{level}":

"{description}"

Using this context, generate 5 statements that would be classified as coming from an "{level}" Spanish speaker. The statements should be rather brief, as if they were part of a conversation, but need not only be one sentence. Each statement should vary in length, from 1–3 sentences. Only provide the statements–do NOT provide English translations.
"""

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from concurrent.futures import ThreadPoolExecutor
from openai import OpenAI

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

def process_level(level, description, i):
    print(f"Processing level {level}: iter {i}")
    # print(PROMPT.format(level=level, description=description),)
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": PROMPT.format(level=level, description=description),
            },
        ],
        model="gpt-3.5-turbo",
        temperature=1.3,
        frequency_penalty=0.7
    )

    response = chat_completion.choices[0].message.content

    with open(f"../data/guideline-data/{level}/{i}.txt", 'w') as file:
        file.write(response)

# %%
import time

with ThreadPoolExecutor() as executor:
    for level, description in guidelines.items():
        futures = []
        # Use the executor to submit the tasks in parallel
        for i in range(20):
            futures.append(executor.submit(process_level, level, description, i))
            # Delay to preserve QPS
            time.sleep(.5)

        # Wait for all tasks to complete before moving to the next level
        for future in futures:
            future.result()
# Out:
# Processing level Advanced Mid: iter 0
# Processing level Advanced Mid: iter 1
# Processing level Advanced Mid: iter 2
# Processing level Advanced Mid: iter 3
# Processing level Advanced Mid: iter 4
# Processing level Advanced Mid: iter 5
# Processing level Advanced Mid: iter 6
# Processing level Advanced Mid: iter 7
# Processing level Advanced Mid: iter 8
# Processing level Advanced Mid: iter 9
# Processing level Advanced Mid: iter 10
# Processing level Advanced Mid: iter 11
# Processing level Advanced Mid: iter 12
# Processing level Advanced Mid: iter 13
# Processing level Advanced Mid: iter 14
# Processing level Advanced Mid: iter 15
# Processing level Advanced Mid: iter 16
# Processing level Advanced Mid: iter 17
# Processing level Advanced Mid: iter 18
# Processing level Advanced Mid: iter 19
# Processing level Distinguished: iter 0
# Processing level Distinguished: iter 1
# Processing level Distinguished: iter 2
# Processing level Distinguished: iter 3
# Processing level Distinguished: iter 4
# Processing level Distinguished: iter 5
# Processing level Distinguished: iter 6
# Processing level Distinguished: iter 7
# Processing level Distinguished: iter 8
# Processing level Distinguished: iter 9
# Processing level Distinguished: iter 10
# Processing level Distinguished: iter 11
# Processing level Distinguished: iter 12
# Processing level Distinguished: iter 13
# Processing level Distinguished: iter 14
# Processing level Distinguished: iter 15
# Processing level Distinguished: iter 16
# Processing level Distinguished: iter 17
# Processing level Distinguished: iter 18
# Processing level Distinguished: iter 19
# Processing level Advanced Low: iter 0
# Processing level Advanced Low: iter 1
# Processing level Advanced Low: iter 2
# Processing level Advanced Low: iter 3
# Processing level Advanced Low: iter 4
# Processing level Advanced Low: iter 5
# Processing level Advanced Low: iter 6
# Processing level Advanced Low: iter 7
# Processing level Advanced Low: iter 8
# Processing level Advanced Low: iter 9
# Processing level Advanced Low: iter 10
# Processing level Advanced Low: iter 11
# Processing level Advanced Low: iter 12
# Processing level Advanced Low: iter 13
# Processing level Advanced Low: iter 14
# Processing level Advanced Low: iter 15
# Processing level Advanced Low: iter 16
# Processing level Advanced Low: iter 17
# Processing level Advanced Low: iter 18
# Processing level Advanced Low: iter 19
# Processing level Intermediate High: iter 0
# Processing level Intermediate High: iter 1
# Processing level Intermediate High: iter 2
# Processing level Intermediate High: iter 3
# Processing level Intermediate High: iter 4
# Processing level Intermediate High: iter 5
# Processing level Intermediate High: iter 6
# Processing level Intermediate High: iter 7
# Processing level Intermediate High: iter 8
# Processing level Intermediate High: iter 9
# Processing level Intermediate High: iter 10
# Processing level Intermediate High: iter 11
# Processing level Intermediate High: iter 12
# Processing level Intermediate High: iter 13
# Processing level Intermediate High: iter 14
# Processing level Intermediate High: iter 15
# Processing level Intermediate High: iter 16
# Processing level Intermediate High: iter 17
# Processing level Intermediate High: iter 18
# Processing level Intermediate High: iter 19
# Processing level Novice Low: iter 0
# Processing level Novice Low: iter 1
# Processing level Novice Low: iter 2
# Processing level Novice Low: iter 3
# Processing level Novice Low: iter 4
# Processing level Novice Low: iter 5
# Processing level Novice Low: iter 6
# Processing level Novice Low: iter 7
# Processing level Novice Low: iter 8
# Processing level Novice Low: iter 9
# Processing level Novice Low: iter 10
# Processing level Novice Low: iter 11
# Processing level Novice Low: iter 12
# Processing level Novice Low: iter 13
# Processing level Novice Low: iter 14
# Processing level Novice Low: iter 15
# Processing level Novice Low: iter 16
# Processing level Novice Low: iter 17
# Processing level Novice Low: iter 18
# Processing level Novice Low: iter 19
# Processing level Intermediate Mid: iter 0
# Processing level Intermediate Mid: iter 1
# Processing level Intermediate Mid: iter 2
# Processing level Intermediate Mid: iter 3
# Processing level Intermediate Mid: iter 4
# Processing level Intermediate Mid: iter 5
# Processing level Intermediate Mid: iter 6
# Processing level Intermediate Mid: iter 7
# Processing level Intermediate Mid: iter 8
# Processing level Intermediate Mid: iter 9
# Processing level Intermediate Mid: iter 10
# Processing level Intermediate Mid: iter 11
# Processing level Intermediate Mid: iter 12
# Processing level Intermediate Mid: iter 13
# Processing level Intermediate Mid: iter 14
# Processing level Intermediate Mid: iter 15
# Processing level Intermediate Mid: iter 16
# Processing level Intermediate Mid: iter 17
# Processing level Intermediate Mid: iter 18
# Processing level Intermediate Mid: iter 19
# Processing level Novice High: iter 0
# Processing level Novice High: iter 1
# Processing level Novice High: iter 2
# Processing level Novice High: iter 3
# Processing level Novice High: iter 4
# Processing level Novice High: iter 5
# Processing level Novice High: iter 6
# Processing level Novice High: iter 7
# Processing level Novice High: iter 8
# Processing level Novice High: iter 9
# Processing level Novice High: iter 10
# Processing level Novice High: iter 11
# Processing level Novice High: iter 12
# Processing level Novice High: iter 13
# Processing level Novice High: iter 14
# Processing level Novice High: iter 15
# Processing level Novice High: iter 16
# Processing level Novice High: iter 17
# Processing level Novice High: iter 18
# Processing level Novice High: iter 19
# Processing level Novice Mid: iter 0
# Processing level Novice Mid: iter 1
# Processing level Novice Mid: iter 2
# Processing level Novice Mid: iter 3
# Processing level Novice Mid: iter 4
# Processing level Novice Mid: iter 5
# Processing level Novice Mid: iter 6
# Processing level Novice Mid: iter 7
# Processing level Novice Mid: iter 8
# Processing level Novice Mid: iter 9
# Processing level Novice Mid: iter 10
# Processing level Novice Mid: iter 11
# Processing level Novice Mid: iter 12
# Processing level Novice Mid: iter 13
# Processing level Novice Mid: iter 14
# Processing level Novice Mid: iter 15
# Processing level Novice Mid: iter 16
# Processing level Novice Mid: iter 17
# Processing level Novice Mid: iter 18
# Processing level Novice Mid: iter 19
# Processing level Intermediate Low: iter 0
# Processing level Intermediate Low: iter 1
# Processing level Intermediate Low: iter 2
# Processing level Intermediate Low: iter 3
# Processing level Intermediate Low: iter 4
# Processing level Intermediate Low: iter 5
# Processing level Intermediate Low: iter 6
# Processing level Intermediate Low: iter 7
# Processing level Intermediate Low: iter 8
# Processing level Intermediate Low: iter 9
# Processing level Intermediate Low: iter 10
# Processing level Intermediate Low: iter 11
# Processing level Intermediate Low: iter 12
# Processing level Intermediate Low: iter 13
# Processing level Intermediate Low: iter 14
# Processing level Intermediate Low: iter 15
# Processing level Intermediate Low: iter 16
# Processing level Intermediate Low: iter 17
# Processing level Intermediate Low: iter 18
# Processing level Intermediate Low: iter 19
# Processing level Superior: iter 0
# Processing level Superior: iter 1
# Processing level Superior: iter 2
# Processing level Superior: iter 3
# Processing level Superior: iter 4
# Processing level Superior: iter 5
# Processing level Superior: iter 6
# Processing level Superior: iter 7
# Processing level Superior: iter 8
# Processing level Superior: iter 9
# Processing level Superior: iter 10
# Processing level Superior: iter 11
# Processing level Superior: iter 12
# Processing level Superior: iter 13
# Processing level Superior: iter 14
# Processing level Superior: iter 15
# Processing level Superior: iter 16
# Processing level Superior: iter 17
# Processing level Superior: iter 18
# Processing level Superior: iter 19
# Processing level Advanced High: iter 0
# Processing level Advanced High: iter 1
# Processing level Advanced High: iter 2
# Processing level Advanced High: iter 3
# Processing level Advanced High: iter 4
# Processing level Advanced High: iter 5
# Processing level Advanced High: iter 6
# Processing level Advanced High: iter 7
# Processing level Advanced High: iter 8
# Processing level Advanced High: iter 9
# Processing level Advanced High: iter 10
# Processing level Advanced High: iter 11
# Processing level Advanced High: iter 12
# Processing level Advanced High: iter 13
# Processing level Advanced High: iter 14
# Processing level Advanced High: iter 15
# Processing level Advanced High: iter 16
# Processing level Advanced High: iter 17
# Processing level Advanced High: iter 18
# Processing level Advanced High: iter 19

# %%
def remove_blank_lines(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Remove blank lines
    non_blank_lines = [line.strip() for line in lines if line.strip()]

    with open(file_path, 'w') as file:
        file.write('\n'.join(non_blank_lines))

def process_folder(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file_name in files:
            if file_name.endswith('.txt'):
                file_path = os.path.join(root, file_name)
                remove_blank_lines(file_path)
                print(f"Processed: {file_path}")

folder_path = '../data/guideline-data'
process_folder(folder_path)
# Out:
# Processed: ../data/guideline-data/Advanced High/15.txt
# Processed: ../data/guideline-data/Advanced High/14.txt
# Processed: ../data/guideline-data/Advanced High/16.txt
# Processed: ../data/guideline-data/Advanced High/17.txt
# Processed: ../data/guideline-data/Advanced High/13.txt
# Processed: ../data/guideline-data/Advanced High/12.txt
# Processed: ../data/guideline-data/Advanced High/10.txt
# Processed: ../data/guideline-data/Advanced High/11.txt
# Processed: ../data/guideline-data/Advanced High/9.txt
# Processed: ../data/guideline-data/Advanced High/8.txt
# Processed: ../data/guideline-data/Advanced High/5.txt
# Processed: ../data/guideline-data/Advanced High/4.txt
# Processed: ../data/guideline-data/Advanced High/6.txt
# Processed: ../data/guideline-data/Advanced High/7.txt
# Processed: ../data/guideline-data/Advanced High/3.txt
# Processed: ../data/guideline-data/Advanced High/2.txt
# Processed: ../data/guideline-data/Advanced High/0.txt
# Processed: ../data/guideline-data/Advanced High/1.txt
# Processed: ../data/guideline-data/Advanced High/19.txt
# Processed: ../data/guideline-data/Advanced High/18.txt
# Processed: ../data/guideline-data/Intermediate High/15.txt
# Processed: ../data/guideline-data/Intermediate High/14.txt
# Processed: ../data/guideline-data/Intermediate High/16.txt
# Processed: ../data/guideline-data/Intermediate High/17.txt
# Processed: ../data/guideline-data/Intermediate High/13.txt
# Processed: ../data/guideline-data/Intermediate High/12.txt
# Processed: ../data/guideline-data/Intermediate High/10.txt
# Processed: ../data/guideline-data/Intermediate High/11.txt
# Processed: ../data/guideline-data/Intermediate High/9.txt
# Processed: ../data/guideline-data/Intermediate High/8.txt
# Processed: ../data/guideline-data/Intermediate High/5.txt
# Processed: ../data/guideline-data/Intermediate High/4.txt
# Processed: ../data/guideline-data/Intermediate High/6.txt
# Processed: ../data/guideline-data/Intermediate High/7.txt
# Processed: ../data/guideline-data/Intermediate High/3.txt
# Processed: ../data/guideline-data/Intermediate High/2.txt
# Processed: ../data/guideline-data/Intermediate High/0.txt
# Processed: ../data/guideline-data/Intermediate High/1.txt
# Processed: ../data/guideline-data/Intermediate High/19.txt
# Processed: ../data/guideline-data/Intermediate High/18.txt
# Processed: ../data/guideline-data/Intermediate Mid/15.txt
# Processed: ../data/guideline-data/Intermediate Mid/14.txt
# Processed: ../data/guideline-data/Intermediate Mid/16.txt
# Processed: ../data/guideline-data/Intermediate Mid/17.txt
# Processed: ../data/guideline-data/Intermediate Mid/13.txt
# Processed: ../data/guideline-data/Intermediate Mid/12.txt
# Processed: ../data/guideline-data/Intermediate Mid/10.txt
# Processed: ../data/guideline-data/Intermediate Mid/11.txt
# Processed: ../data/guideline-data/Intermediate Mid/9.txt
# Processed: ../data/guideline-data/Intermediate Mid/8.txt
# Processed: ../data/guideline-data/Intermediate Mid/5.txt
# Processed: ../data/guideline-data/Intermediate Mid/4.txt
# Processed: ../data/guideline-data/Intermediate Mid/6.txt
# Processed: ../data/guideline-data/Intermediate Mid/7.txt
# Processed: ../data/guideline-data/Intermediate Mid/3.txt
# Processed: ../data/guideline-data/Intermediate Mid/2.txt
# Processed: ../data/guideline-data/Intermediate Mid/0.txt
# Processed: ../data/guideline-data/Intermediate Mid/1.txt
# Processed: ../data/guideline-data/Intermediate Mid/19.txt
# Processed: ../data/guideline-data/Intermediate Mid/18.txt
# Processed: ../data/guideline-data/Intermediate Low/15.txt
# Processed: ../data/guideline-data/Intermediate Low/14.txt
# Processed: ../data/guideline-data/Intermediate Low/16.txt
# Processed: ../data/guideline-data/Intermediate Low/17.txt
# Processed: ../data/guideline-data/Intermediate Low/13.txt
# Processed: ../data/guideline-data/Intermediate Low/12.txt
# Processed: ../data/guideline-data/Intermediate Low/10.txt
# Processed: ../data/guideline-data/Intermediate Low/11.txt
# Processed: ../data/guideline-data/Intermediate Low/9.txt
# Processed: ../data/guideline-data/Intermediate Low/8.txt
# Processed: ../data/guideline-data/Intermediate Low/5.txt
# Processed: ../data/guideline-data/Intermediate Low/4.txt
# Processed: ../data/guideline-data/Intermediate Low/6.txt
# Processed: ../data/guideline-data/Intermediate Low/7.txt
# Processed: ../data/guideline-data/Intermediate Low/3.txt
# Processed: ../data/guideline-data/Intermediate Low/2.txt
# Processed: ../data/guideline-data/Intermediate Low/0.txt
# Processed: ../data/guideline-data/Intermediate Low/1.txt
# Processed: ../data/guideline-data/Intermediate Low/19.txt
# Processed: ../data/guideline-data/Intermediate Low/18.txt
# Processed: ../data/guideline-data/Novice High/15.txt
# Processed: ../data/guideline-data/Novice High/14.txt
# Processed: ../data/guideline-data/Novice High/16.txt
# Processed: ../data/guideline-data/Novice High/17.txt
# Processed: ../data/guideline-data/Novice High/13.txt
# Processed: ../data/guideline-data/Novice High/12.txt
# Processed: ../data/guideline-data/Novice High/10.txt
# Processed: ../data/guideline-data/Novice High/11.txt
# Processed: ../data/guideline-data/Novice High/9.txt
# Processed: ../data/guideline-data/Novice High/8.txt
# Processed: ../data/guideline-data/Novice High/5.txt
# Processed: ../data/guideline-data/Novice High/4.txt
# Processed: ../data/guideline-data/Novice High/6.txt
# Processed: ../data/guideline-data/Novice High/7.txt
# Processed: ../data/guideline-data/Novice High/3.txt
# Processed: ../data/guideline-data/Novice High/2.txt
# Processed: ../data/guideline-data/Novice High/0.txt
# Processed: ../data/guideline-data/Novice High/1.txt
# Processed: ../data/guideline-data/Novice High/19.txt
# Processed: ../data/guideline-data/Novice High/18.txt
# Processed: ../data/guideline-data/Superior/15.txt
# Processed: ../data/guideline-data/Superior/14.txt
# Processed: ../data/guideline-data/Superior/16.txt
# Processed: ../data/guideline-data/Superior/17.txt
# Processed: ../data/guideline-data/Superior/13.txt
# Processed: ../data/guideline-data/Superior/12.txt
# Processed: ../data/guideline-data/Superior/10.txt
# Processed: ../data/guideline-data/Superior/11.txt
# Processed: ../data/guideline-data/Superior/9.txt
# Processed: ../data/guideline-data/Superior/8.txt
# Processed: ../data/guideline-data/Superior/5.txt
# Processed: ../data/guideline-data/Superior/4.txt
# Processed: ../data/guideline-data/Superior/6.txt
# Processed: ../data/guideline-data/Superior/7.txt
# Processed: ../data/guideline-data/Superior/3.txt
# Processed: ../data/guideline-data/Superior/2.txt
# Processed: ../data/guideline-data/Superior/0.txt
# Processed: ../data/guideline-data/Superior/1.txt
# Processed: ../data/guideline-data/Superior/19.txt
# Processed: ../data/guideline-data/Superior/18.txt
# Processed: ../data/guideline-data/Advanced Mid/15.txt
# Processed: ../data/guideline-data/Advanced Mid/14.txt
# Processed: ../data/guideline-data/Advanced Mid/16.txt
# Processed: ../data/guideline-data/Advanced Mid/17.txt
# Processed: ../data/guideline-data/Advanced Mid/13.txt
# Processed: ../data/guideline-data/Advanced Mid/12.txt
# Processed: ../data/guideline-data/Advanced Mid/10.txt
# Processed: ../data/guideline-data/Advanced Mid/11.txt
# Processed: ../data/guideline-data/Advanced Mid/9.txt
# Processed: ../data/guideline-data/Advanced Mid/8.txt
# Processed: ../data/guideline-data/Advanced Mid/5.txt
# Processed: ../data/guideline-data/Advanced Mid/4.txt
# Processed: ../data/guideline-data/Advanced Mid/6.txt
# Processed: ../data/guideline-data/Advanced Mid/7.txt
# Processed: ../data/guideline-data/Advanced Mid/3.txt
# Processed: ../data/guideline-data/Advanced Mid/2.txt
# Processed: ../data/guideline-data/Advanced Mid/0.txt
# Processed: ../data/guideline-data/Advanced Mid/1.txt
# Processed: ../data/guideline-data/Advanced Mid/19.txt
# Processed: ../data/guideline-data/Advanced Mid/18.txt
# Processed: ../data/guideline-data/Novice Mid/15.txt
# Processed: ../data/guideline-data/Novice Mid/14.txt
# Processed: ../data/guideline-data/Novice Mid/16.txt
# Processed: ../data/guideline-data/Novice Mid/17.txt
# Processed: ../data/guideline-data/Novice Mid/13.txt
# Processed: ../data/guideline-data/Novice Mid/12.txt
# Processed: ../data/guideline-data/Novice Mid/10.txt
# Processed: ../data/guideline-data/Novice Mid/11.txt
# Processed: ../data/guideline-data/Novice Mid/9.txt
# Processed: ../data/guideline-data/Novice Mid/8.txt
# Processed: ../data/guideline-data/Novice Mid/5.txt
# Processed: ../data/guideline-data/Novice Mid/4.txt
# Processed: ../data/guideline-data/Novice Mid/6.txt
# Processed: ../data/guideline-data/Novice Mid/7.txt
# Processed: ../data/guideline-data/Novice Mid/3.txt
# Processed: ../data/guideline-data/Novice Mid/2.txt
# Processed: ../data/guideline-data/Novice Mid/0.txt
# Processed: ../data/guideline-data/Novice Mid/1.txt
# Processed: ../data/guideline-data/Novice Mid/19.txt
# Processed: ../data/guideline-data/Novice Mid/18.txt
# Processed: ../data/guideline-data/Advanced Low/15.txt
# Processed: ../data/guideline-data/Advanced Low/14.txt
# Processed: ../data/guideline-data/Advanced Low/16.txt
# Processed: ../data/guideline-data/Advanced Low/17.txt
# Processed: ../data/guideline-data/Advanced Low/13.txt
# Processed: ../data/guideline-data/Advanced Low/12.txt
# Processed: ../data/guideline-data/Advanced Low/10.txt
# Processed: ../data/guideline-data/Advanced Low/11.txt
# Processed: ../data/guideline-data/Advanced Low/9.txt
# Processed: ../data/guideline-data/Advanced Low/8.txt
# Processed: ../data/guideline-data/Advanced Low/5.txt
# Processed: ../data/guideline-data/Advanced Low/4.txt
# Processed: ../data/guideline-data/Advanced Low/6.txt
# Processed: ../data/guideline-data/Advanced Low/7.txt
# Processed: ../data/guideline-data/Advanced Low/3.txt
# Processed: ../data/guideline-data/Advanced Low/2.txt
# Processed: ../data/guideline-data/Advanced Low/0.txt
# Processed: ../data/guideline-data/Advanced Low/1.txt
# Processed: ../data/guideline-data/Advanced Low/19.txt
# Processed: ../data/guideline-data/Advanced Low/18.txt
# Processed: ../data/guideline-data/Novice Low/15.txt
# Processed: ../data/guideline-data/Novice Low/14.txt
# Processed: ../data/guideline-data/Novice Low/16.txt
# Processed: ../data/guideline-data/Novice Low/17.txt
# Processed: ../data/guideline-data/Novice Low/13.txt
# Processed: ../data/guideline-data/Novice Low/12.txt
# Processed: ../data/guideline-data/Novice Low/10.txt
# Processed: ../data/guideline-data/Novice Low/11.txt
# Processed: ../data/guideline-data/Novice Low/9.txt
# Processed: ../data/guideline-data/Novice Low/8.txt
# Processed: ../data/guideline-data/Novice Low/5.txt
# Processed: ../data/guideline-data/Novice Low/4.txt
# Processed: ../data/guideline-data/Novice Low/6.txt
# Processed: ../data/guideline-data/Novice Low/7.txt
# Processed: ../data/guideline-data/Novice Low/3.txt
# Processed: ../data/guideline-data/Novice Low/2.txt
# Processed: ../data/guideline-data/Novice Low/0.txt
# Processed: ../data/guideline-data/Novice Low/1.txt
# Processed: ../data/guideline-data/Novice Low/19.txt
# Processed: ../data/guideline-data/Novice Low/18.txt
# Processed: ../data/guideline-data/Distinguished/15.txt
# Processed: ../data/guideline-data/Distinguished/14.txt
# Processed: ../data/guideline-data/Distinguished/16.txt
# Processed: ../data/guideline-data/Distinguished/17.txt
# Processed: ../data/guideline-data/Distinguished/13.txt
# Processed: ../data/guideline-data/Distinguished/12.txt
# Processed: ../data/guideline-data/Distinguished/10.txt
# Processed: ../data/guideline-data/Distinguished/11.txt
# Processed: ../data/guideline-data/Distinguished/9.txt
# Processed: ../data/guideline-data/Distinguished/8.txt
# Processed: ../data/guideline-data/Distinguished/5.txt
# Processed: ../data/guideline-data/Distinguished/4.txt
# Processed: ../data/guideline-data/Distinguished/6.txt
# Processed: ../data/guideline-data/Distinguished/7.txt
# Processed: ../data/guideline-data/Distinguished/3.txt
# Processed: ../data/guideline-data/Distinguished/2.txt
# Processed: ../data/guideline-data/Distinguished/0.txt
# Processed: ../data/guideline-data/Distinguished/1.txt
# Processed: ../data/guideline-data/Distinguished/19.txt
# Processed: ../data/guideline-data/Distinguished/18.txt

# %%
def split_markdown_list(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        
    file_num = int(file_path.split('/')[-1].split('.')[0])
    
    lines = content.split('\n')
    i = 0
    for line in lines:
        line = line.strip()[3:]
        item_file_name = f"item{file_num * 5 + i}.txt"
        
        item_file_path = os.path.join(os.path.dirname(file_path), item_file_name)
        with open(item_file_path, 'w') as item_file:
            item_file.write(line)

        print(f"Created: {item_file_path}")
        i += 1

def process_folder(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file_name in files:
            if file_name.endswith('.txt'):
                file_path = os.path.join(root, file_name)
                split_markdown_list(file_path)
                print(f"Processed: {file_path}")

folder_path = '../data/guideline-data'
process_folder(folder_path)
# Out:
# Created: ../data/guideline-data/Advanced High/item75.txt
# Created: ../data/guideline-data/Advanced High/item76.txt
# Created: ../data/guideline-data/Advanced High/item77.txt
# Created: ../data/guideline-data/Advanced High/item78.txt
# Created: ../data/guideline-data/Advanced High/item79.txt
# Processed: ../data/guideline-data/Advanced High/15.txt
# Created: ../data/guideline-data/Advanced High/item70.txt
# Created: ../data/guideline-data/Advanced High/item71.txt
# Created: ../data/guideline-data/Advanced High/item72.txt
# Created: ../data/guideline-data/Advanced High/item73.txt
# Created: ../data/guideline-data/Advanced High/item74.txt
# Processed: ../data/guideline-data/Advanced High/14.txt
# Created: ../data/guideline-data/Advanced High/item80.txt
# Created: ../data/guideline-data/Advanced High/item81.txt
# Created: ../data/guideline-data/Advanced High/item82.txt
# Created: ../data/guideline-data/Advanced High/item83.txt
# Created: ../data/guideline-data/Advanced High/item84.txt
# Processed: ../data/guideline-data/Advanced High/16.txt
# Created: ../data/guideline-data/Advanced High/item85.txt
# Created: ../data/guideline-data/Advanced High/item86.txt
# Created: ../data/guideline-data/Advanced High/item87.txt
# Created: ../data/guideline-data/Advanced High/item88.txt
# Created: ../data/guideline-data/Advanced High/item89.txt
# Processed: ../data/guideline-data/Advanced High/17.txt
# Created: ../data/guideline-data/Advanced High/item65.txt
# Created: ../data/guideline-data/Advanced High/item66.txt
# Created: ../data/guideline-data/Advanced High/item67.txt
# Created: ../data/guideline-data/Advanced High/item68.txt
# Created: ../data/guideline-data/Advanced High/item69.txt
# Processed: ../data/guideline-data/Advanced High/13.txt
# Created: ../data/guideline-data/Advanced High/item60.txt
# Created: ../data/guideline-data/Advanced High/item61.txt
# Created: ../data/guideline-data/Advanced High/item62.txt
# Created: ../data/guideline-data/Advanced High/item63.txt
# Created: ../data/guideline-data/Advanced High/item64.txt
# Processed: ../data/guideline-data/Advanced High/12.txt
# Created: ../data/guideline-data/Advanced High/item50.txt
# Created: ../data/guideline-data/Advanced High/item51.txt
# Created: ../data/guideline-data/Advanced High/item52.txt
# Created: ../data/guideline-data/Advanced High/item53.txt
# Created: ../data/guideline-data/Advanced High/item54.txt
# Processed: ../data/guideline-data/Advanced High/10.txt
# Created: ../data/guideline-data/Advanced High/item55.txt
# Created: ../data/guideline-data/Advanced High/item56.txt
# Created: ../data/guideline-data/Advanced High/item57.txt
# Created: ../data/guideline-data/Advanced High/item58.txt
# Created: ../data/guideline-data/Advanced High/item59.txt
# Processed: ../data/guideline-data/Advanced High/11.txt
# Created: ../data/guideline-data/Advanced High/item45.txt
# Created: ../data/guideline-data/Advanced High/item46.txt
# Created: ../data/guideline-data/Advanced High/item47.txt
# Created: ../data/guideline-data/Advanced High/item48.txt
# Created: ../data/guideline-data/Advanced High/item49.txt
# Processed: ../data/guideline-data/Advanced High/9.txt
# Created: ../data/guideline-data/Advanced High/item40.txt
# Created: ../data/guideline-data/Advanced High/item41.txt
# Created: ../data/guideline-data/Advanced High/item42.txt
# Created: ../data/guideline-data/Advanced High/item43.txt
# Created: ../data/guideline-data/Advanced High/item44.txt
# Processed: ../data/guideline-data/Advanced High/8.txt
# Created: ../data/guideline-data/Advanced High/item25.txt
# Created: ../data/guideline-data/Advanced High/item26.txt
# Created: ../data/guideline-data/Advanced High/item27.txt
# Created: ../data/guideline-data/Advanced High/item28.txt
# Created: ../data/guideline-data/Advanced High/item29.txt
# Processed: ../data/guideline-data/Advanced High/5.txt
# Created: ../data/guideline-data/Advanced High/item20.txt
# Created: ../data/guideline-data/Advanced High/item21.txt
# Created: ../data/guideline-data/Advanced High/item22.txt
# Created: ../data/guideline-data/Advanced High/item23.txt
# Created: ../data/guideline-data/Advanced High/item24.txt
# Processed: ../data/guideline-data/Advanced High/4.txt
# Created: ../data/guideline-data/Advanced High/item30.txt
# Created: ../data/guideline-data/Advanced High/item31.txt
# Created: ../data/guideline-data/Advanced High/item32.txt
# Created: ../data/guideline-data/Advanced High/item33.txt
# Created: ../data/guideline-data/Advanced High/item34.txt
# Processed: ../data/guideline-data/Advanced High/6.txt
# Created: ../data/guideline-data/Advanced High/item35.txt
# Created: ../data/guideline-data/Advanced High/item36.txt
# Created: ../data/guideline-data/Advanced High/item37.txt
# Created: ../data/guideline-data/Advanced High/item38.txt
# Created: ../data/guideline-data/Advanced High/item39.txt
# Processed: ../data/guideline-data/Advanced High/7.txt
# Created: ../data/guideline-data/Advanced High/item15.txt
# Created: ../data/guideline-data/Advanced High/item16.txt
# Created: ../data/guideline-data/Advanced High/item17.txt
# Created: ../data/guideline-data/Advanced High/item18.txt
# Created: ../data/guideline-data/Advanced High/item19.txt
# Processed: ../data/guideline-data/Advanced High/3.txt
# Created: ../data/guideline-data/Advanced High/item10.txt
# Created: ../data/guideline-data/Advanced High/item11.txt
# Created: ../data/guideline-data/Advanced High/item12.txt
# Created: ../data/guideline-data/Advanced High/item13.txt
# Created: ../data/guideline-data/Advanced High/item14.txt
# Processed: ../data/guideline-data/Advanced High/2.txt
# Created: ../data/guideline-data/Advanced High/item0.txt
# Created: ../data/guideline-data/Advanced High/item1.txt
# Created: ../data/guideline-data/Advanced High/item2.txt
# Created: ../data/guideline-data/Advanced High/item3.txt
# Created: ../data/guideline-data/Advanced High/item4.txt
# Processed: ../data/guideline-data/Advanced High/0.txt
# Created: ../data/guideline-data/Advanced High/item5.txt
# Created: ../data/guideline-data/Advanced High/item6.txt
# Created: ../data/guideline-data/Advanced High/item7.txt
# Created: ../data/guideline-data/Advanced High/item8.txt
# Created: ../data/guideline-data/Advanced High/item9.txt
# Processed: ../data/guideline-data/Advanced High/1.txt
# Created: ../data/guideline-data/Advanced High/item95.txt
# Created: ../data/guideline-data/Advanced High/item96.txt
# Created: ../data/guideline-data/Advanced High/item97.txt
# Created: ../data/guideline-data/Advanced High/item98.txt
# Created: ../data/guideline-data/Advanced High/item99.txt
# Processed: ../data/guideline-data/Advanced High/19.txt
# Created: ../data/guideline-data/Advanced High/item90.txt
# Created: ../data/guideline-data/Advanced High/item91.txt
# Created: ../data/guideline-data/Advanced High/item92.txt
# Created: ../data/guideline-data/Advanced High/item93.txt
# Created: ../data/guideline-data/Advanced High/item94.txt
# Processed: ../data/guideline-data/Advanced High/18.txt
# Created: ../data/guideline-data/Intermediate High/item75.txt
# Created: ../data/guideline-data/Intermediate High/item76.txt
# Created: ../data/guideline-data/Intermediate High/item77.txt
# Created: ../data/guideline-data/Intermediate High/item78.txt
# Created: ../data/guideline-data/Intermediate High/item79.txt
# Processed: ../data/guideline-data/Intermediate High/15.txt
# Created: ../data/guideline-data/Intermediate High/item70.txt
# Created: ../data/guideline-data/Intermediate High/item71.txt
# Created: ../data/guideline-data/Intermediate High/item72.txt
# Created: ../data/guideline-data/Intermediate High/item73.txt
# Created: ../data/guideline-data/Intermediate High/item74.txt
# Processed: ../data/guideline-data/Intermediate High/14.txt
# Created: ../data/guideline-data/Intermediate High/item80.txt
# Created: ../data/guideline-data/Intermediate High/item81.txt
# Created: ../data/guideline-data/Intermediate High/item82.txt
# Created: ../data/guideline-data/Intermediate High/item83.txt
# Created: ../data/guideline-data/Intermediate High/item84.txt
# Processed: ../data/guideline-data/Intermediate High/16.txt
# Created: ../data/guideline-data/Intermediate High/item85.txt
# Created: ../data/guideline-data/Intermediate High/item86.txt
# Created: ../data/guideline-data/Intermediate High/item87.txt
# Created: ../data/guideline-data/Intermediate High/item88.txt
# Created: ../data/guideline-data/Intermediate High/item89.txt
# Processed: ../data/guideline-data/Intermediate High/17.txt
# Created: ../data/guideline-data/Intermediate High/item65.txt
# Created: ../data/guideline-data/Intermediate High/item66.txt
# Created: ../data/guideline-data/Intermediate High/item67.txt
# Created: ../data/guideline-data/Intermediate High/item68.txt
# Created: ../data/guideline-data/Intermediate High/item69.txt
# Processed: ../data/guideline-data/Intermediate High/13.txt
# Created: ../data/guideline-data/Intermediate High/item60.txt
# Created: ../data/guideline-data/Intermediate High/item61.txt
# Created: ../data/guideline-data/Intermediate High/item62.txt
# Created: ../data/guideline-data/Intermediate High/item63.txt
# Created: ../data/guideline-data/Intermediate High/item64.txt
# Processed: ../data/guideline-data/Intermediate High/12.txt
# Created: ../data/guideline-data/Intermediate High/item50.txt
# Created: ../data/guideline-data/Intermediate High/item51.txt
# Created: ../data/guideline-data/Intermediate High/item52.txt
# Created: ../data/guideline-data/Intermediate High/item53.txt
# Created: ../data/guideline-data/Intermediate High/item54.txt
# Processed: ../data/guideline-data/Intermediate High/10.txt
# Created: ../data/guideline-data/Intermediate High/item55.txt
# Created: ../data/guideline-data/Intermediate High/item56.txt
# Created: ../data/guideline-data/Intermediate High/item57.txt
# Created: ../data/guideline-data/Intermediate High/item58.txt
# Created: ../data/guideline-data/Intermediate High/item59.txt
# Processed: ../data/guideline-data/Intermediate High/11.txt
# Created: ../data/guideline-data/Intermediate High/item45.txt
# Created: ../data/guideline-data/Intermediate High/item46.txt
# Created: ../data/guideline-data/Intermediate High/item47.txt
# Created: ../data/guideline-data/Intermediate High/item48.txt
# Created: ../data/guideline-data/Intermediate High/item49.txt
# Processed: ../data/guideline-data/Intermediate High/9.txt
# Created: ../data/guideline-data/Intermediate High/item40.txt
# Created: ../data/guideline-data/Intermediate High/item41.txt
# Created: ../data/guideline-data/Intermediate High/item42.txt
# Created: ../data/guideline-data/Intermediate High/item43.txt
# Created: ../data/guideline-data/Intermediate High/item44.txt
# Processed: ../data/guideline-data/Intermediate High/8.txt
# Created: ../data/guideline-data/Intermediate High/item25.txt
# Created: ../data/guideline-data/Intermediate High/item26.txt
# Created: ../data/guideline-data/Intermediate High/item27.txt
# Created: ../data/guideline-data/Intermediate High/item28.txt
# Created: ../data/guideline-data/Intermediate High/item29.txt
# Processed: ../data/guideline-data/Intermediate High/5.txt
# Created: ../data/guideline-data/Intermediate High/item20.txt
# Created: ../data/guideline-data/Intermediate High/item21.txt
# Created: ../data/guideline-data/Intermediate High/item22.txt
# Created: ../data/guideline-data/Intermediate High/item23.txt
# Created: ../data/guideline-data/Intermediate High/item24.txt
# Processed: ../data/guideline-data/Intermediate High/4.txt
# Created: ../data/guideline-data/Intermediate High/item30.txt
# Created: ../data/guideline-data/Intermediate High/item31.txt
# Created: ../data/guideline-data/Intermediate High/item32.txt
# Created: ../data/guideline-data/Intermediate High/item33.txt
# Created: ../data/guideline-data/Intermediate High/item34.txt
# Processed: ../data/guideline-data/Intermediate High/6.txt
# Created: ../data/guideline-data/Intermediate High/item35.txt
# Created: ../data/guideline-data/Intermediate High/item36.txt
# Created: ../data/guideline-data/Intermediate High/item37.txt
# Created: ../data/guideline-data/Intermediate High/item38.txt
# Created: ../data/guideline-data/Intermediate High/item39.txt
# Processed: ../data/guideline-data/Intermediate High/7.txt
# Created: ../data/guideline-data/Intermediate High/item15.txt
# Created: ../data/guideline-data/Intermediate High/item16.txt
# Created: ../data/guideline-data/Intermediate High/item17.txt
# Created: ../data/guideline-data/Intermediate High/item18.txt
# Created: ../data/guideline-data/Intermediate High/item19.txt
# Processed: ../data/guideline-data/Intermediate High/3.txt
# Created: ../data/guideline-data/Intermediate High/item10.txt
# Created: ../data/guideline-data/Intermediate High/item11.txt
# Created: ../data/guideline-data/Intermediate High/item12.txt
# Created: ../data/guideline-data/Intermediate High/item13.txt
# Created: ../data/guideline-data/Intermediate High/item14.txt
# Processed: ../data/guideline-data/Intermediate High/2.txt
# Created: ../data/guideline-data/Intermediate High/item0.txt
# Created: ../data/guideline-data/Intermediate High/item1.txt
# Created: ../data/guideline-data/Intermediate High/item2.txt
# Created: ../data/guideline-data/Intermediate High/item3.txt
# Created: ../data/guideline-data/Intermediate High/item4.txt
# Processed: ../data/guideline-data/Intermediate High/0.txt
# Created: ../data/guideline-data/Intermediate High/item5.txt
# Created: ../data/guideline-data/Intermediate High/item6.txt
# Created: ../data/guideline-data/Intermediate High/item7.txt
# Created: ../data/guideline-data/Intermediate High/item8.txt
# Created: ../data/guideline-data/Intermediate High/item9.txt
# Processed: ../data/guideline-data/Intermediate High/1.txt
# Created: ../data/guideline-data/Intermediate High/item95.txt
# Created: ../data/guideline-data/Intermediate High/item96.txt
# Created: ../data/guideline-data/Intermediate High/item97.txt
# Created: ../data/guideline-data/Intermediate High/item98.txt
# Created: ../data/guideline-data/Intermediate High/item99.txt
# Processed: ../data/guideline-data/Intermediate High/19.txt
# Created: ../data/guideline-data/Intermediate High/item90.txt
# Created: ../data/guideline-data/Intermediate High/item91.txt
# Created: ../data/guideline-data/Intermediate High/item92.txt
# Created: ../data/guideline-data/Intermediate High/item93.txt
# Created: ../data/guideline-data/Intermediate High/item94.txt
# Processed: ../data/guideline-data/Intermediate High/18.txt
# Created: ../data/guideline-data/Intermediate Mid/item75.txt
# Created: ../data/guideline-data/Intermediate Mid/item76.txt
# Created: ../data/guideline-data/Intermediate Mid/item77.txt
# Created: ../data/guideline-data/Intermediate Mid/item78.txt
# Created: ../data/guideline-data/Intermediate Mid/item79.txt
# Processed: ../data/guideline-data/Intermediate Mid/15.txt
# Created: ../data/guideline-data/Intermediate Mid/item70.txt
# Created: ../data/guideline-data/Intermediate Mid/item71.txt
# Created: ../data/guideline-data/Intermediate Mid/item72.txt
# Created: ../data/guideline-data/Intermediate Mid/item73.txt
# Created: ../data/guideline-data/Intermediate Mid/item74.txt
# Processed: ../data/guideline-data/Intermediate Mid/14.txt
# Created: ../data/guideline-data/Intermediate Mid/item80.txt
# Created: ../data/guideline-data/Intermediate Mid/item81.txt
# Created: ../data/guideline-data/Intermediate Mid/item82.txt
# Created: ../data/guideline-data/Intermediate Mid/item83.txt
# Created: ../data/guideline-data/Intermediate Mid/item84.txt
# Processed: ../data/guideline-data/Intermediate Mid/16.txt
# Created: ../data/guideline-data/Intermediate Mid/item85.txt
# Created: ../data/guideline-data/Intermediate Mid/item86.txt
# Created: ../data/guideline-data/Intermediate Mid/item87.txt
# Created: ../data/guideline-data/Intermediate Mid/item88.txt
# Created: ../data/guideline-data/Intermediate Mid/item89.txt
# Processed: ../data/guideline-data/Intermediate Mid/17.txt
# Created: ../data/guideline-data/Intermediate Mid/item65.txt
# Created: ../data/guideline-data/Intermediate Mid/item66.txt
# Created: ../data/guideline-data/Intermediate Mid/item67.txt
# Created: ../data/guideline-data/Intermediate Mid/item68.txt
# Created: ../data/guideline-data/Intermediate Mid/item69.txt
# Processed: ../data/guideline-data/Intermediate Mid/13.txt
# Created: ../data/guideline-data/Intermediate Mid/item60.txt
# Created: ../data/guideline-data/Intermediate Mid/item61.txt
# Created: ../data/guideline-data/Intermediate Mid/item62.txt
# Created: ../data/guideline-data/Intermediate Mid/item63.txt
# Created: ../data/guideline-data/Intermediate Mid/item64.txt
# Processed: ../data/guideline-data/Intermediate Mid/12.txt
# Created: ../data/guideline-data/Intermediate Mid/item50.txt
# Created: ../data/guideline-data/Intermediate Mid/item51.txt
# Created: ../data/guideline-data/Intermediate Mid/item52.txt
# Created: ../data/guideline-data/Intermediate Mid/item53.txt
# Created: ../data/guideline-data/Intermediate Mid/item54.txt
# Processed: ../data/guideline-data/Intermediate Mid/10.txt
# Created: ../data/guideline-data/Intermediate Mid/item55.txt
# Created: ../data/guideline-data/Intermediate Mid/item56.txt
# Created: ../data/guideline-data/Intermediate Mid/item57.txt
# Created: ../data/guideline-data/Intermediate Mid/item58.txt
# Created: ../data/guideline-data/Intermediate Mid/item59.txt
# Processed: ../data/guideline-data/Intermediate Mid/11.txt
# Created: ../data/guideline-data/Intermediate Mid/item45.txt
# Created: ../data/guideline-data/Intermediate Mid/item46.txt
# Created: ../data/guideline-data/Intermediate Mid/item47.txt
# Created: ../data/guideline-data/Intermediate Mid/item48.txt
# Created: ../data/guideline-data/Intermediate Mid/item49.txt
# Processed: ../data/guideline-data/Intermediate Mid/9.txt
# Created: ../data/guideline-data/Intermediate Mid/item40.txt
# Created: ../data/guideline-data/Intermediate Mid/item41.txt
# Created: ../data/guideline-data/Intermediate Mid/item42.txt
# Created: ../data/guideline-data/Intermediate Mid/item43.txt
# Created: ../data/guideline-data/Intermediate Mid/item44.txt
# Processed: ../data/guideline-data/Intermediate Mid/8.txt
# Created: ../data/guideline-data/Intermediate Mid/item25.txt
# Created: ../data/guideline-data/Intermediate Mid/item26.txt
# Created: ../data/guideline-data/Intermediate Mid/item27.txt
# Created: ../data/guideline-data/Intermediate Mid/item28.txt
# Created: ../data/guideline-data/Intermediate Mid/item29.txt
# Processed: ../data/guideline-data/Intermediate Mid/5.txt
# Created: ../data/guideline-data/Intermediate Mid/item20.txt
# Created: ../data/guideline-data/Intermediate Mid/item21.txt
# Created: ../data/guideline-data/Intermediate Mid/item22.txt
# Created: ../data/guideline-data/Intermediate Mid/item23.txt
# Created: ../data/guideline-data/Intermediate Mid/item24.txt
# Processed: ../data/guideline-data/Intermediate Mid/4.txt
# Created: ../data/guideline-data/Intermediate Mid/item30.txt
# Created: ../data/guideline-data/Intermediate Mid/item31.txt
# Created: ../data/guideline-data/Intermediate Mid/item32.txt
# Created: ../data/guideline-data/Intermediate Mid/item33.txt
# Created: ../data/guideline-data/Intermediate Mid/item34.txt
# Processed: ../data/guideline-data/Intermediate Mid/6.txt
# Created: ../data/guideline-data/Intermediate Mid/item35.txt
# Created: ../data/guideline-data/Intermediate Mid/item36.txt
# Created: ../data/guideline-data/Intermediate Mid/item37.txt
# Created: ../data/guideline-data/Intermediate Mid/item38.txt
# Created: ../data/guideline-data/Intermediate Mid/item39.txt
# Processed: ../data/guideline-data/Intermediate Mid/7.txt
# Created: ../data/guideline-data/Intermediate Mid/item15.txt
# Created: ../data/guideline-data/Intermediate Mid/item16.txt
# Created: ../data/guideline-data/Intermediate Mid/item17.txt
# Created: ../data/guideline-data/Intermediate Mid/item18.txt
# Created: ../data/guideline-data/Intermediate Mid/item19.txt
# Processed: ../data/guideline-data/Intermediate Mid/3.txt
# Created: ../data/guideline-data/Intermediate Mid/item10.txt
# Created: ../data/guideline-data/Intermediate Mid/item11.txt
# Created: ../data/guideline-data/Intermediate Mid/item12.txt
# Created: ../data/guideline-data/Intermediate Mid/item13.txt
# Created: ../data/guideline-data/Intermediate Mid/item14.txt
# Processed: ../data/guideline-data/Intermediate Mid/2.txt
# Created: ../data/guideline-data/Intermediate Mid/item0.txt
# Created: ../data/guideline-data/Intermediate Mid/item1.txt
# Created: ../data/guideline-data/Intermediate Mid/item2.txt
# Created: ../data/guideline-data/Intermediate Mid/item3.txt
# Created: ../data/guideline-data/Intermediate Mid/item4.txt
# Processed: ../data/guideline-data/Intermediate Mid/0.txt
# Created: ../data/guideline-data/Intermediate Mid/item5.txt
# Created: ../data/guideline-data/Intermediate Mid/item6.txt
# Created: ../data/guideline-data/Intermediate Mid/item7.txt
# Created: ../data/guideline-data/Intermediate Mid/item8.txt
# Created: ../data/guideline-data/Intermediate Mid/item9.txt
# Processed: ../data/guideline-data/Intermediate Mid/1.txt
# Created: ../data/guideline-data/Intermediate Mid/item95.txt
# Created: ../data/guideline-data/Intermediate Mid/item96.txt
# Created: ../data/guideline-data/Intermediate Mid/item97.txt
# Created: ../data/guideline-data/Intermediate Mid/item98.txt
# Created: ../data/guideline-data/Intermediate Mid/item99.txt
# Processed: ../data/guideline-data/Intermediate Mid/19.txt
# Created: ../data/guideline-data/Intermediate Mid/item90.txt
# Created: ../data/guideline-data/Intermediate Mid/item91.txt
# Created: ../data/guideline-data/Intermediate Mid/item92.txt
# Created: ../data/guideline-data/Intermediate Mid/item93.txt
# Created: ../data/guideline-data/Intermediate Mid/item94.txt
# Processed: ../data/guideline-data/Intermediate Mid/18.txt
# Created: ../data/guideline-data/Intermediate Low/item75.txt
# Created: ../data/guideline-data/Intermediate Low/item76.txt
# Created: ../data/guideline-data/Intermediate Low/item77.txt
# Created: ../data/guideline-data/Intermediate Low/item78.txt
# Created: ../data/guideline-data/Intermediate Low/item79.txt
# Processed: ../data/guideline-data/Intermediate Low/15.txt
# Created: ../data/guideline-data/Intermediate Low/item70.txt
# Created: ../data/guideline-data/Intermediate Low/item71.txt
# Created: ../data/guideline-data/Intermediate Low/item72.txt
# Created: ../data/guideline-data/Intermediate Low/item73.txt
# Created: ../data/guideline-data/Intermediate Low/item74.txt
# Processed: ../data/guideline-data/Intermediate Low/14.txt
# Created: ../data/guideline-data/Intermediate Low/item80.txt
# Created: ../data/guideline-data/Intermediate Low/item81.txt
# Created: ../data/guideline-data/Intermediate Low/item82.txt
# Created: ../data/guideline-data/Intermediate Low/item83.txt
# Created: ../data/guideline-data/Intermediate Low/item84.txt
# Processed: ../data/guideline-data/Intermediate Low/16.txt
# Created: ../data/guideline-data/Intermediate Low/item85.txt
# Created: ../data/guideline-data/Intermediate Low/item86.txt
# Created: ../data/guideline-data/Intermediate Low/item87.txt
# Created: ../data/guideline-data/Intermediate Low/item88.txt
# Created: ../data/guideline-data/Intermediate Low/item89.txt
# Processed: ../data/guideline-data/Intermediate Low/17.txt
# Created: ../data/guideline-data/Intermediate Low/item65.txt
# Created: ../data/guideline-data/Intermediate Low/item66.txt
# Created: ../data/guideline-data/Intermediate Low/item67.txt
# Created: ../data/guideline-data/Intermediate Low/item68.txt
# Created: ../data/guideline-data/Intermediate Low/item69.txt
# Processed: ../data/guideline-data/Intermediate Low/13.txt
# Created: ../data/guideline-data/Intermediate Low/item60.txt
# Created: ../data/guideline-data/Intermediate Low/item61.txt
# Created: ../data/guideline-data/Intermediate Low/item62.txt
# Created: ../data/guideline-data/Intermediate Low/item63.txt
# Created: ../data/guideline-data/Intermediate Low/item64.txt
# Processed: ../data/guideline-data/Intermediate Low/12.txt
# Created: ../data/guideline-data/Intermediate Low/item50.txt
# Created: ../data/guideline-data/Intermediate Low/item51.txt
# Created: ../data/guideline-data/Intermediate Low/item52.txt
# Created: ../data/guideline-data/Intermediate Low/item53.txt
# Created: ../data/guideline-data/Intermediate Low/item54.txt
# Processed: ../data/guideline-data/Intermediate Low/10.txt
# Created: ../data/guideline-data/Intermediate Low/item55.txt
# Created: ../data/guideline-data/Intermediate Low/item56.txt
# Created: ../data/guideline-data/Intermediate Low/item57.txt
# Created: ../data/guideline-data/Intermediate Low/item58.txt
# Created: ../data/guideline-data/Intermediate Low/item59.txt
# Processed: ../data/guideline-data/Intermediate Low/11.txt
# Created: ../data/guideline-data/Intermediate Low/item45.txt
# Created: ../data/guideline-data/Intermediate Low/item46.txt
# Created: ../data/guideline-data/Intermediate Low/item47.txt
# Created: ../data/guideline-data/Intermediate Low/item48.txt
# Created: ../data/guideline-data/Intermediate Low/item49.txt
# Processed: ../data/guideline-data/Intermediate Low/9.txt
# Created: ../data/guideline-data/Intermediate Low/item40.txt
# Created: ../data/guideline-data/Intermediate Low/item41.txt
# Created: ../data/guideline-data/Intermediate Low/item42.txt
# Created: ../data/guideline-data/Intermediate Low/item43.txt
# Created: ../data/guideline-data/Intermediate Low/item44.txt
# Processed: ../data/guideline-data/Intermediate Low/8.txt
# Created: ../data/guideline-data/Intermediate Low/item25.txt
# Created: ../data/guideline-data/Intermediate Low/item26.txt
# Created: ../data/guideline-data/Intermediate Low/item27.txt
# Created: ../data/guideline-data/Intermediate Low/item28.txt
# Created: ../data/guideline-data/Intermediate Low/item29.txt
# Processed: ../data/guideline-data/Intermediate Low/5.txt
# Created: ../data/guideline-data/Intermediate Low/item20.txt
# Created: ../data/guideline-data/Intermediate Low/item21.txt
# Created: ../data/guideline-data/Intermediate Low/item22.txt
# Created: ../data/guideline-data/Intermediate Low/item23.txt
# Created: ../data/guideline-data/Intermediate Low/item24.txt
# Processed: ../data/guideline-data/Intermediate Low/4.txt
# Created: ../data/guideline-data/Intermediate Low/item30.txt
# Created: ../data/guideline-data/Intermediate Low/item31.txt
# Created: ../data/guideline-data/Intermediate Low/item32.txt
# Created: ../data/guideline-data/Intermediate Low/item33.txt
# Created: ../data/guideline-data/Intermediate Low/item34.txt
# Processed: ../data/guideline-data/Intermediate Low/6.txt
# Created: ../data/guideline-data/Intermediate Low/item35.txt
# Created: ../data/guideline-data/Intermediate Low/item36.txt
# Created: ../data/guideline-data/Intermediate Low/item37.txt
# Created: ../data/guideline-data/Intermediate Low/item38.txt
# Created: ../data/guideline-data/Intermediate Low/item39.txt
# Processed: ../data/guideline-data/Intermediate Low/7.txt
# Created: ../data/guideline-data/Intermediate Low/item15.txt
# Created: ../data/guideline-data/Intermediate Low/item16.txt
# Created: ../data/guideline-data/Intermediate Low/item17.txt
# Created: ../data/guideline-data/Intermediate Low/item18.txt
# Created: ../data/guideline-data/Intermediate Low/item19.txt
# Processed: ../data/guideline-data/Intermediate Low/3.txt
# Created: ../data/guideline-data/Intermediate Low/item10.txt
# Created: ../data/guideline-data/Intermediate Low/item11.txt
# Created: ../data/guideline-data/Intermediate Low/item12.txt
# Created: ../data/guideline-data/Intermediate Low/item13.txt
# Created: ../data/guideline-data/Intermediate Low/item14.txt
# Processed: ../data/guideline-data/Intermediate Low/2.txt
# Created: ../data/guideline-data/Intermediate Low/item0.txt
# Created: ../data/guideline-data/Intermediate Low/item1.txt
# Created: ../data/guideline-data/Intermediate Low/item2.txt
# Created: ../data/guideline-data/Intermediate Low/item3.txt
# Created: ../data/guideline-data/Intermediate Low/item4.txt
# Processed: ../data/guideline-data/Intermediate Low/0.txt
# Created: ../data/guideline-data/Intermediate Low/item5.txt
# Created: ../data/guideline-data/Intermediate Low/item6.txt
# Created: ../data/guideline-data/Intermediate Low/item7.txt
# Created: ../data/guideline-data/Intermediate Low/item8.txt
# Created: ../data/guideline-data/Intermediate Low/item9.txt
# Processed: ../data/guideline-data/Intermediate Low/1.txt
# Created: ../data/guideline-data/Intermediate Low/item95.txt
# Created: ../data/guideline-data/Intermediate Low/item96.txt
# Created: ../data/guideline-data/Intermediate Low/item97.txt
# Created: ../data/guideline-data/Intermediate Low/item98.txt
# Created: ../data/guideline-data/Intermediate Low/item99.txt
# Processed: ../data/guideline-data/Intermediate Low/19.txt
# Created: ../data/guideline-data/Intermediate Low/item90.txt
# Created: ../data/guideline-data/Intermediate Low/item91.txt
# Created: ../data/guideline-data/Intermediate Low/item92.txt
# Created: ../data/guideline-data/Intermediate Low/item93.txt
# Created: ../data/guideline-data/Intermediate Low/item94.txt
# Processed: ../data/guideline-data/Intermediate Low/18.txt
# Created: ../data/guideline-data/Novice High/item75.txt
# Created: ../data/guideline-data/Novice High/item76.txt
# Created: ../data/guideline-data/Novice High/item77.txt
# Created: ../data/guideline-data/Novice High/item78.txt
# Created: ../data/guideline-data/Novice High/item79.txt
# Processed: ../data/guideline-data/Novice High/15.txt
# Created: ../data/guideline-data/Novice High/item70.txt
# Created: ../data/guideline-data/Novice High/item71.txt
# Created: ../data/guideline-data/Novice High/item72.txt
# Created: ../data/guideline-data/Novice High/item73.txt
# Created: ../data/guideline-data/Novice High/item74.txt
# Processed: ../data/guideline-data/Novice High/14.txt
# Created: ../data/guideline-data/Novice High/item80.txt
# Created: ../data/guideline-data/Novice High/item81.txt
# Created: ../data/guideline-data/Novice High/item82.txt
# Created: ../data/guideline-data/Novice High/item83.txt
# Created: ../data/guideline-data/Novice High/item84.txt
# Processed: ../data/guideline-data/Novice High/16.txt
# Created: ../data/guideline-data/Novice High/item85.txt
# Created: ../data/guideline-data/Novice High/item86.txt
# Created: ../data/guideline-data/Novice High/item87.txt
# Created: ../data/guideline-data/Novice High/item88.txt
# Created: ../data/guideline-data/Novice High/item89.txt
# Processed: ../data/guideline-data/Novice High/17.txt
# Created: ../data/guideline-data/Novice High/item65.txt
# Created: ../data/guideline-data/Novice High/item66.txt
# Created: ../data/guideline-data/Novice High/item67.txt
# Created: ../data/guideline-data/Novice High/item68.txt
# Created: ../data/guideline-data/Novice High/item69.txt
# Processed: ../data/guideline-data/Novice High/13.txt
# Created: ../data/guideline-data/Novice High/item60.txt
# Created: ../data/guideline-data/Novice High/item61.txt
# Created: ../data/guideline-data/Novice High/item62.txt
# Created: ../data/guideline-data/Novice High/item63.txt
# Created: ../data/guideline-data/Novice High/item64.txt
# Processed: ../data/guideline-data/Novice High/12.txt
# Created: ../data/guideline-data/Novice High/item50.txt
# Created: ../data/guideline-data/Novice High/item51.txt
# Created: ../data/guideline-data/Novice High/item52.txt
# Created: ../data/guideline-data/Novice High/item53.txt
# Created: ../data/guideline-data/Novice High/item54.txt
# Processed: ../data/guideline-data/Novice High/10.txt
# Created: ../data/guideline-data/Novice High/item55.txt
# Created: ../data/guideline-data/Novice High/item56.txt
# Created: ../data/guideline-data/Novice High/item57.txt
# Created: ../data/guideline-data/Novice High/item58.txt
# Created: ../data/guideline-data/Novice High/item59.txt
# Processed: ../data/guideline-data/Novice High/11.txt
# Created: ../data/guideline-data/Novice High/item45.txt
# Created: ../data/guideline-data/Novice High/item46.txt
# Created: ../data/guideline-data/Novice High/item47.txt
# Created: ../data/guideline-data/Novice High/item48.txt
# Created: ../data/guideline-data/Novice High/item49.txt
# Processed: ../data/guideline-data/Novice High/9.txt
# Created: ../data/guideline-data/Novice High/item40.txt
# Created: ../data/guideline-data/Novice High/item41.txt
# Created: ../data/guideline-data/Novice High/item42.txt
# Created: ../data/guideline-data/Novice High/item43.txt
# Created: ../data/guideline-data/Novice High/item44.txt
# Processed: ../data/guideline-data/Novice High/8.txt
# Created: ../data/guideline-data/Novice High/item25.txt
# Created: ../data/guideline-data/Novice High/item26.txt
# Created: ../data/guideline-data/Novice High/item27.txt
# Created: ../data/guideline-data/Novice High/item28.txt
# Created: ../data/guideline-data/Novice High/item29.txt
# Processed: ../data/guideline-data/Novice High/5.txt
# Created: ../data/guideline-data/Novice High/item20.txt
# Created: ../data/guideline-data/Novice High/item21.txt
# Created: ../data/guideline-data/Novice High/item22.txt
# Created: ../data/guideline-data/Novice High/item23.txt
# Created: ../data/guideline-data/Novice High/item24.txt
# Processed: ../data/guideline-data/Novice High/4.txt
# Created: ../data/guideline-data/Novice High/item30.txt
# Created: ../data/guideline-data/Novice High/item31.txt
# Created: ../data/guideline-data/Novice High/item32.txt
# Created: ../data/guideline-data/Novice High/item33.txt
# Created: ../data/guideline-data/Novice High/item34.txt
# Processed: ../data/guideline-data/Novice High/6.txt
# Created: ../data/guideline-data/Novice High/item35.txt
# Created: ../data/guideline-data/Novice High/item36.txt
# Created: ../data/guideline-data/Novice High/item37.txt
# Created: ../data/guideline-data/Novice High/item38.txt
# Created: ../data/guideline-data/Novice High/item39.txt
# Processed: ../data/guideline-data/Novice High/7.txt
# Created: ../data/guideline-data/Novice High/item15.txt
# Created: ../data/guideline-data/Novice High/item16.txt
# Created: ../data/guideline-data/Novice High/item17.txt
# Created: ../data/guideline-data/Novice High/item18.txt
# Created: ../data/guideline-data/Novice High/item19.txt
# Processed: ../data/guideline-data/Novice High/3.txt
# Created: ../data/guideline-data/Novice High/item10.txt
# Created: ../data/guideline-data/Novice High/item11.txt
# Created: ../data/guideline-data/Novice High/item12.txt
# Created: ../data/guideline-data/Novice High/item13.txt
# Created: ../data/guideline-data/Novice High/item14.txt
# Processed: ../data/guideline-data/Novice High/2.txt
# Created: ../data/guideline-data/Novice High/item0.txt
# Created: ../data/guideline-data/Novice High/item1.txt
# Created: ../data/guideline-data/Novice High/item2.txt
# Created: ../data/guideline-data/Novice High/item3.txt
# Created: ../data/guideline-data/Novice High/item4.txt
# Processed: ../data/guideline-data/Novice High/0.txt
# Created: ../data/guideline-data/Novice High/item5.txt
# Created: ../data/guideline-data/Novice High/item6.txt
# Created: ../data/guideline-data/Novice High/item7.txt
# Created: ../data/guideline-data/Novice High/item8.txt
# Created: ../data/guideline-data/Novice High/item9.txt
# Processed: ../data/guideline-data/Novice High/1.txt
# Created: ../data/guideline-data/Novice High/item95.txt
# Created: ../data/guideline-data/Novice High/item96.txt
# Created: ../data/guideline-data/Novice High/item97.txt
# Created: ../data/guideline-data/Novice High/item98.txt
# Created: ../data/guideline-data/Novice High/item99.txt
# Processed: ../data/guideline-data/Novice High/19.txt
# Created: ../data/guideline-data/Novice High/item90.txt
# Created: ../data/guideline-data/Novice High/item91.txt
# Created: ../data/guideline-data/Novice High/item92.txt
# Created: ../data/guideline-data/Novice High/item93.txt
# Created: ../data/guideline-data/Novice High/item94.txt
# Processed: ../data/guideline-data/Novice High/18.txt
# Created: ../data/guideline-data/Superior/item75.txt
# Created: ../data/guideline-data/Superior/item76.txt
# Created: ../data/guideline-data/Superior/item77.txt
# Created: ../data/guideline-data/Superior/item78.txt
# Created: ../data/guideline-data/Superior/item79.txt
# Processed: ../data/guideline-data/Superior/15.txt
# Created: ../data/guideline-data/Superior/item70.txt
# Created: ../data/guideline-data/Superior/item71.txt
# Created: ../data/guideline-data/Superior/item72.txt
# Created: ../data/guideline-data/Superior/item73.txt
# Created: ../data/guideline-data/Superior/item74.txt
# Processed: ../data/guideline-data/Superior/14.txt
# Created: ../data/guideline-data/Superior/item80.txt
# Created: ../data/guideline-data/Superior/item81.txt
# Created: ../data/guideline-data/Superior/item82.txt
# Created: ../data/guideline-data/Superior/item83.txt
# Created: ../data/guideline-data/Superior/item84.txt
# Processed: ../data/guideline-data/Superior/16.txt
# Created: ../data/guideline-data/Superior/item85.txt
# Created: ../data/guideline-data/Superior/item86.txt
# Created: ../data/guideline-data/Superior/item87.txt
# Created: ../data/guideline-data/Superior/item88.txt
# Created: ../data/guideline-data/Superior/item89.txt
# Processed: ../data/guideline-data/Superior/17.txt
# Created: ../data/guideline-data/Superior/item65.txt
# Created: ../data/guideline-data/Superior/item66.txt
# Created: ../data/guideline-data/Superior/item67.txt
# Created: ../data/guideline-data/Superior/item68.txt
# Created: ../data/guideline-data/Superior/item69.txt
# Processed: ../data/guideline-data/Superior/13.txt
# Created: ../data/guideline-data/Superior/item60.txt
# Created: ../data/guideline-data/Superior/item61.txt
# Created: ../data/guideline-data/Superior/item62.txt
# Created: ../data/guideline-data/Superior/item63.txt
# Created: ../data/guideline-data/Superior/item64.txt
# Processed: ../data/guideline-data/Superior/12.txt
# Created: ../data/guideline-data/Superior/item50.txt
# Created: ../data/guideline-data/Superior/item51.txt
# Created: ../data/guideline-data/Superior/item52.txt
# Created: ../data/guideline-data/Superior/item53.txt
# Created: ../data/guideline-data/Superior/item54.txt
# Processed: ../data/guideline-data/Superior/10.txt
# Created: ../data/guideline-data/Superior/item55.txt
# Created: ../data/guideline-data/Superior/item56.txt
# Created: ../data/guideline-data/Superior/item57.txt
# Created: ../data/guideline-data/Superior/item58.txt
# Created: ../data/guideline-data/Superior/item59.txt
# Processed: ../data/guideline-data/Superior/11.txt
# Created: ../data/guideline-data/Superior/item45.txt
# Created: ../data/guideline-data/Superior/item46.txt
# Created: ../data/guideline-data/Superior/item47.txt
# Created: ../data/guideline-data/Superior/item48.txt
# Created: ../data/guideline-data/Superior/item49.txt
# Processed: ../data/guideline-data/Superior/9.txt
# Created: ../data/guideline-data/Superior/item40.txt
# Created: ../data/guideline-data/Superior/item41.txt
# Created: ../data/guideline-data/Superior/item42.txt
# Created: ../data/guideline-data/Superior/item43.txt
# Created: ../data/guideline-data/Superior/item44.txt
# Processed: ../data/guideline-data/Superior/8.txt
# Created: ../data/guideline-data/Superior/item25.txt
# Created: ../data/guideline-data/Superior/item26.txt
# Created: ../data/guideline-data/Superior/item27.txt
# Created: ../data/guideline-data/Superior/item28.txt
# Created: ../data/guideline-data/Superior/item29.txt
# Processed: ../data/guideline-data/Superior/5.txt
# Created: ../data/guideline-data/Superior/item20.txt
# Created: ../data/guideline-data/Superior/item21.txt
# Created: ../data/guideline-data/Superior/item22.txt
# Created: ../data/guideline-data/Superior/item23.txt
# Created: ../data/guideline-data/Superior/item24.txt
# Processed: ../data/guideline-data/Superior/4.txt
# Created: ../data/guideline-data/Superior/item30.txt
# Created: ../data/guideline-data/Superior/item31.txt
# Created: ../data/guideline-data/Superior/item32.txt
# Created: ../data/guideline-data/Superior/item33.txt
# Created: ../data/guideline-data/Superior/item34.txt
# Processed: ../data/guideline-data/Superior/6.txt
# Created: ../data/guideline-data/Superior/item35.txt
# Created: ../data/guideline-data/Superior/item36.txt
# Created: ../data/guideline-data/Superior/item37.txt
# Created: ../data/guideline-data/Superior/item38.txt
# Created: ../data/guideline-data/Superior/item39.txt
# Processed: ../data/guideline-data/Superior/7.txt
# Created: ../data/guideline-data/Superior/item15.txt
# Created: ../data/guideline-data/Superior/item16.txt
# Created: ../data/guideline-data/Superior/item17.txt
# Created: ../data/guideline-data/Superior/item18.txt
# Created: ../data/guideline-data/Superior/item19.txt
# Processed: ../data/guideline-data/Superior/3.txt
# Created: ../data/guideline-data/Superior/item10.txt
# Created: ../data/guideline-data/Superior/item11.txt
# Created: ../data/guideline-data/Superior/item12.txt
# Created: ../data/guideline-data/Superior/item13.txt
# Created: ../data/guideline-data/Superior/item14.txt
# Processed: ../data/guideline-data/Superior/2.txt
# Created: ../data/guideline-data/Superior/item0.txt
# Created: ../data/guideline-data/Superior/item1.txt
# Created: ../data/guideline-data/Superior/item2.txt
# Created: ../data/guideline-data/Superior/item3.txt
# Created: ../data/guideline-data/Superior/item4.txt
# Processed: ../data/guideline-data/Superior/0.txt
# Created: ../data/guideline-data/Superior/item5.txt
# Created: ../data/guideline-data/Superior/item6.txt
# Created: ../data/guideline-data/Superior/item7.txt
# Created: ../data/guideline-data/Superior/item8.txt
# Created: ../data/guideline-data/Superior/item9.txt
# Processed: ../data/guideline-data/Superior/1.txt
# Created: ../data/guideline-data/Superior/item95.txt
# Created: ../data/guideline-data/Superior/item96.txt
# Created: ../data/guideline-data/Superior/item97.txt
# Created: ../data/guideline-data/Superior/item98.txt
# Created: ../data/guideline-data/Superior/item99.txt
# Processed: ../data/guideline-data/Superior/19.txt
# Created: ../data/guideline-data/Superior/item90.txt
# Created: ../data/guideline-data/Superior/item91.txt
# Created: ../data/guideline-data/Superior/item92.txt
# Created: ../data/guideline-data/Superior/item93.txt
# Created: ../data/guideline-data/Superior/item94.txt
# Processed: ../data/guideline-data/Superior/18.txt
# Created: ../data/guideline-data/Advanced Mid/item75.txt
# Created: ../data/guideline-data/Advanced Mid/item76.txt
# Created: ../data/guideline-data/Advanced Mid/item77.txt
# Created: ../data/guideline-data/Advanced Mid/item78.txt
# Created: ../data/guideline-data/Advanced Mid/item79.txt
# Processed: ../data/guideline-data/Advanced Mid/15.txt
# Created: ../data/guideline-data/Advanced Mid/item70.txt
# Created: ../data/guideline-data/Advanced Mid/item71.txt
# Created: ../data/guideline-data/Advanced Mid/item72.txt
# Created: ../data/guideline-data/Advanced Mid/item73.txt
# Created: ../data/guideline-data/Advanced Mid/item74.txt
# Processed: ../data/guideline-data/Advanced Mid/14.txt
# Created: ../data/guideline-data/Advanced Mid/item80.txt
# Created: ../data/guideline-data/Advanced Mid/item81.txt
# Created: ../data/guideline-data/Advanced Mid/item82.txt
# Created: ../data/guideline-data/Advanced Mid/item83.txt
# Created: ../data/guideline-data/Advanced Mid/item84.txt
# Processed: ../data/guideline-data/Advanced Mid/16.txt
# Created: ../data/guideline-data/Advanced Mid/item85.txt
# Created: ../data/guideline-data/Advanced Mid/item86.txt
# Created: ../data/guideline-data/Advanced Mid/item87.txt
# Created: ../data/guideline-data/Advanced Mid/item88.txt
# Created: ../data/guideline-data/Advanced Mid/item89.txt
# Processed: ../data/guideline-data/Advanced Mid/17.txt
# Created: ../data/guideline-data/Advanced Mid/item65.txt
# Created: ../data/guideline-data/Advanced Mid/item66.txt
# Created: ../data/guideline-data/Advanced Mid/item67.txt
# Created: ../data/guideline-data/Advanced Mid/item68.txt
# Created: ../data/guideline-data/Advanced Mid/item69.txt
# Processed: ../data/guideline-data/Advanced Mid/13.txt
# Created: ../data/guideline-data/Advanced Mid/item60.txt
# Created: ../data/guideline-data/Advanced Mid/item61.txt
# Created: ../data/guideline-data/Advanced Mid/item62.txt
# Created: ../data/guideline-data/Advanced Mid/item63.txt
# Created: ../data/guideline-data/Advanced Mid/item64.txt
# Processed: ../data/guideline-data/Advanced Mid/12.txt
# Created: ../data/guideline-data/Advanced Mid/item50.txt
# Created: ../data/guideline-data/Advanced Mid/item51.txt
# Created: ../data/guideline-data/Advanced Mid/item52.txt
# Created: ../data/guideline-data/Advanced Mid/item53.txt
# Created: ../data/guideline-data/Advanced Mid/item54.txt
# Processed: ../data/guideline-data/Advanced Mid/10.txt
# Created: ../data/guideline-data/Advanced Mid/item55.txt
# Created: ../data/guideline-data/Advanced Mid/item56.txt
# Created: ../data/guideline-data/Advanced Mid/item57.txt
# Created: ../data/guideline-data/Advanced Mid/item58.txt
# Created: ../data/guideline-data/Advanced Mid/item59.txt
# Processed: ../data/guideline-data/Advanced Mid/11.txt
# Created: ../data/guideline-data/Advanced Mid/item45.txt
# Created: ../data/guideline-data/Advanced Mid/item46.txt
# Created: ../data/guideline-data/Advanced Mid/item47.txt
# Created: ../data/guideline-data/Advanced Mid/item48.txt
# Created: ../data/guideline-data/Advanced Mid/item49.txt
# Processed: ../data/guideline-data/Advanced Mid/9.txt
# Created: ../data/guideline-data/Advanced Mid/item40.txt
# Created: ../data/guideline-data/Advanced Mid/item41.txt
# Created: ../data/guideline-data/Advanced Mid/item42.txt
# Created: ../data/guideline-data/Advanced Mid/item43.txt
# Created: ../data/guideline-data/Advanced Mid/item44.txt
# Processed: ../data/guideline-data/Advanced Mid/8.txt
# Created: ../data/guideline-data/Advanced Mid/item25.txt
# Created: ../data/guideline-data/Advanced Mid/item26.txt
# Created: ../data/guideline-data/Advanced Mid/item27.txt
# Created: ../data/guideline-data/Advanced Mid/item28.txt
# Created: ../data/guideline-data/Advanced Mid/item29.txt
# Processed: ../data/guideline-data/Advanced Mid/5.txt
# Created: ../data/guideline-data/Advanced Mid/item20.txt
# Created: ../data/guideline-data/Advanced Mid/item21.txt
# Created: ../data/guideline-data/Advanced Mid/item22.txt
# Created: ../data/guideline-data/Advanced Mid/item23.txt
# Created: ../data/guideline-data/Advanced Mid/item24.txt
# Processed: ../data/guideline-data/Advanced Mid/4.txt
# Created: ../data/guideline-data/Advanced Mid/item30.txt
# Created: ../data/guideline-data/Advanced Mid/item31.txt
# Created: ../data/guideline-data/Advanced Mid/item32.txt
# Created: ../data/guideline-data/Advanced Mid/item33.txt
# Created: ../data/guideline-data/Advanced Mid/item34.txt
# Processed: ../data/guideline-data/Advanced Mid/6.txt
# Created: ../data/guideline-data/Advanced Mid/item35.txt
# Created: ../data/guideline-data/Advanced Mid/item36.txt
# Created: ../data/guideline-data/Advanced Mid/item37.txt
# Created: ../data/guideline-data/Advanced Mid/item38.txt
# Created: ../data/guideline-data/Advanced Mid/item39.txt
# Processed: ../data/guideline-data/Advanced Mid/7.txt
# Created: ../data/guideline-data/Advanced Mid/item15.txt
# Created: ../data/guideline-data/Advanced Mid/item16.txt
# Created: ../data/guideline-data/Advanced Mid/item17.txt
# Created: ../data/guideline-data/Advanced Mid/item18.txt
# Created: ../data/guideline-data/Advanced Mid/item19.txt
# Processed: ../data/guideline-data/Advanced Mid/3.txt
# Created: ../data/guideline-data/Advanced Mid/item10.txt
# Created: ../data/guideline-data/Advanced Mid/item11.txt
# Created: ../data/guideline-data/Advanced Mid/item12.txt
# Created: ../data/guideline-data/Advanced Mid/item13.txt
# Created: ../data/guideline-data/Advanced Mid/item14.txt
# Processed: ../data/guideline-data/Advanced Mid/2.txt
# Created: ../data/guideline-data/Advanced Mid/item0.txt
# Created: ../data/guideline-data/Advanced Mid/item1.txt
# Created: ../data/guideline-data/Advanced Mid/item2.txt
# Created: ../data/guideline-data/Advanced Mid/item3.txt
# Created: ../data/guideline-data/Advanced Mid/item4.txt
# Processed: ../data/guideline-data/Advanced Mid/0.txt
# Created: ../data/guideline-data/Advanced Mid/item5.txt
# Created: ../data/guideline-data/Advanced Mid/item6.txt
# Created: ../data/guideline-data/Advanced Mid/item7.txt
# Created: ../data/guideline-data/Advanced Mid/item8.txt
# Created: ../data/guideline-data/Advanced Mid/item9.txt
# Processed: ../data/guideline-data/Advanced Mid/1.txt
# Created: ../data/guideline-data/Advanced Mid/item95.txt
# Created: ../data/guideline-data/Advanced Mid/item96.txt
# Created: ../data/guideline-data/Advanced Mid/item97.txt
# Created: ../data/guideline-data/Advanced Mid/item98.txt
# Created: ../data/guideline-data/Advanced Mid/item99.txt
# Processed: ../data/guideline-data/Advanced Mid/19.txt
# Created: ../data/guideline-data/Advanced Mid/item90.txt
# Created: ../data/guideline-data/Advanced Mid/item91.txt
# Created: ../data/guideline-data/Advanced Mid/item92.txt
# Created: ../data/guideline-data/Advanced Mid/item93.txt
# Created: ../data/guideline-data/Advanced Mid/item94.txt
# Processed: ../data/guideline-data/Advanced Mid/18.txt
# Created: ../data/guideline-data/Novice Mid/item75.txt
# Created: ../data/guideline-data/Novice Mid/item76.txt
# Created: ../data/guideline-data/Novice Mid/item77.txt
# Created: ../data/guideline-data/Novice Mid/item78.txt
# Created: ../data/guideline-data/Novice Mid/item79.txt
# ...
# Created: ../data/guideline-data/Advanced Low/item24.txt
# Processed: ../data/guideline-data/Advanced Low/4.txt
# Created: ../data/guideline-data/Advanced Low/item30.txt
# Created: ../data/guideline-data/Advanced Low/item31.txt
# Created: ../data/guideline-data/Advanced Low/item32.txt
# Created: ../data/guideline-data/Advanced Low/item33.txt
# Created: ../data/guideline-data/Advanced Low/item34.txt
# Processed: ../data/guideline-data/Advanced Low/6.txt
# Created: ../data/guideline-data/Advanced Low/item35.txt
# Created: ../data/guideline-data/Advanced Low/item36.txt
# Created: ../data/guideline-data/Advanced Low/item37.txt
# Created: ../data/guideline-data/Advanced Low/item38.txt
# Created: ../data/guideline-data/Advanced Low/item39.txt
# Processed: ../data/guideline-data/Advanced Low/7.txt
# Created: ../data/guideline-data/Advanced Low/item15.txt
# Created: ../data/guideline-data/Advanced Low/item16.txt
# Created: ../data/guideline-data/Advanced Low/item17.txt
# Created: ../data/guideline-data/Advanced Low/item18.txt
# Created: ../data/guideline-data/Advanced Low/item19.txt
# Processed: ../data/guideline-data/Advanced Low/3.txt
# Created: ../data/guideline-data/Advanced Low/item10.txt
# Created: ../data/guideline-data/Advanced Low/item11.txt
# Created: ../data/guideline-data/Advanced Low/item12.txt
# Created: ../data/guideline-data/Advanced Low/item13.txt
# Created: ../data/guideline-data/Advanced Low/item14.txt
# Processed: ../data/guideline-data/Advanced Low/2.txt
# Created: ../data/guideline-data/Advanced Low/item0.txt
# Created: ../data/guideline-data/Advanced Low/item1.txt
# Created: ../data/guideline-data/Advanced Low/item2.txt
# Created: ../data/guideline-data/Advanced Low/item3.txt
# Created: ../data/guideline-data/Advanced Low/item4.txt
# Processed: ../data/guideline-data/Advanced Low/0.txt
# Created: ../data/guideline-data/Advanced Low/item5.txt
# Created: ../data/guideline-data/Advanced Low/item6.txt
# Created: ../data/guideline-data/Advanced Low/item7.txt
# Created: ../data/guideline-data/Advanced Low/item8.txt
# Created: ../data/guideline-data/Advanced Low/item9.txt
# Processed: ../data/guideline-data/Advanced Low/1.txt
# Created: ../data/guideline-data/Advanced Low/item95.txt
# Created: ../data/guideline-data/Advanced Low/item96.txt
# Created: ../data/guideline-data/Advanced Low/item97.txt
# Created: ../data/guideline-data/Advanced Low/item98.txt
# Created: ../data/guideline-data/Advanced Low/item99.txt
# Processed: ../data/guideline-data/Advanced Low/19.txt
# Created: ../data/guideline-data/Advanced Low/item90.txt
# Created: ../data/guideline-data/Advanced Low/item91.txt
# Created: ../data/guideline-data/Advanced Low/item92.txt
# Created: ../data/guideline-data/Advanced Low/item93.txt
# Created: ../data/guideline-data/Advanced Low/item94.txt
# Processed: ../data/guideline-data/Advanced Low/18.txt
# Created: ../data/guideline-data/Novice Low/item75.txt
# Created: ../data/guideline-data/Novice Low/item76.txt
# Created: ../data/guideline-data/Novice Low/item77.txt
# Created: ../data/guideline-data/Novice Low/item78.txt
# Created: ../data/guideline-data/Novice Low/item79.txt
# Processed: ../data/guideline-data/Novice Low/15.txt
# Created: ../data/guideline-data/Novice Low/item70.txt
# Created: ../data/guideline-data/Novice Low/item71.txt
# Created: ../data/guideline-data/Novice Low/item72.txt
# Created: ../data/guideline-data/Novice Low/item73.txt
# Created: ../data/guideline-data/Novice Low/item74.txt
# Processed: ../data/guideline-data/Novice Low/14.txt
# Created: ../data/guideline-data/Novice Low/item80.txt
# Created: ../data/guideline-data/Novice Low/item81.txt
# Created: ../data/guideline-data/Novice Low/item82.txt
# Created: ../data/guideline-data/Novice Low/item83.txt
# Created: ../data/guideline-data/Novice Low/item84.txt
# Processed: ../data/guideline-data/Novice Low/16.txt
# Created: ../data/guideline-data/Novice Low/item85.txt
# Created: ../data/guideline-data/Novice Low/item86.txt
# Created: ../data/guideline-data/Novice Low/item87.txt
# Created: ../data/guideline-data/Novice Low/item88.txt
# Created: ../data/guideline-data/Novice Low/item89.txt
# Processed: ../data/guideline-data/Novice Low/17.txt
# Created: ../data/guideline-data/Novice Low/item65.txt
# Created: ../data/guideline-data/Novice Low/item66.txt
# Created: ../data/guideline-data/Novice Low/item67.txt
# Created: ../data/guideline-data/Novice Low/item68.txt
# Created: ../data/guideline-data/Novice Low/item69.txt
# Processed: ../data/guideline-data/Novice Low/13.txt
# Created: ../data/guideline-data/Novice Low/item60.txt
# Created: ../data/guideline-data/Novice Low/item61.txt
# Created: ../data/guideline-data/Novice Low/item62.txt
# Created: ../data/guideline-data/Novice Low/item63.txt
# Created: ../data/guideline-data/Novice Low/item64.txt
# Processed: ../data/guideline-data/Novice Low/12.txt
# Created: ../data/guideline-data/Novice Low/item50.txt
# Created: ../data/guideline-data/Novice Low/item51.txt
# Created: ../data/guideline-data/Novice Low/item52.txt
# Created: ../data/guideline-data/Novice Low/item53.txt
# Created: ../data/guideline-data/Novice Low/item54.txt
# Processed: ../data/guideline-data/Novice Low/10.txt
# Created: ../data/guideline-data/Novice Low/item55.txt
# Created: ../data/guideline-data/Novice Low/item56.txt
# Created: ../data/guideline-data/Novice Low/item57.txt
# Created: ../data/guideline-data/Novice Low/item58.txt
# Created: ../data/guideline-data/Novice Low/item59.txt
# Processed: ../data/guideline-data/Novice Low/11.txt
# Created: ../data/guideline-data/Novice Low/item45.txt
# Created: ../data/guideline-data/Novice Low/item46.txt
# Created: ../data/guideline-data/Novice Low/item47.txt
# Created: ../data/guideline-data/Novice Low/item48.txt
# Created: ../data/guideline-data/Novice Low/item49.txt
# Processed: ../data/guideline-data/Novice Low/9.txt
# Created: ../data/guideline-data/Novice Low/item40.txt
# Created: ../data/guideline-data/Novice Low/item41.txt
# Created: ../data/guideline-data/Novice Low/item42.txt
# Created: ../data/guideline-data/Novice Low/item43.txt
# Created: ../data/guideline-data/Novice Low/item44.txt
# Processed: ../data/guideline-data/Novice Low/8.txt
# Created: ../data/guideline-data/Novice Low/item25.txt
# Created: ../data/guideline-data/Novice Low/item26.txt
# Created: ../data/guideline-data/Novice Low/item27.txt
# Created: ../data/guideline-data/Novice Low/item28.txt
# Created: ../data/guideline-data/Novice Low/item29.txt
# Processed: ../data/guideline-data/Novice Low/5.txt
# Created: ../data/guideline-data/Novice Low/item20.txt
# Created: ../data/guideline-data/Novice Low/item21.txt
# Created: ../data/guideline-data/Novice Low/item22.txt
# Created: ../data/guideline-data/Novice Low/item23.txt
# Created: ../data/guideline-data/Novice Low/item24.txt
# Processed: ../data/guideline-data/Novice Low/4.txt
# Created: ../data/guideline-data/Novice Low/item30.txt
# Created: ../data/guideline-data/Novice Low/item31.txt
# Created: ../data/guideline-data/Novice Low/item32.txt
# Created: ../data/guideline-data/Novice Low/item33.txt
# Created: ../data/guideline-data/Novice Low/item34.txt
# Processed: ../data/guideline-data/Novice Low/6.txt
# Created: ../data/guideline-data/Novice Low/item35.txt
# Created: ../data/guideline-data/Novice Low/item36.txt
# Created: ../data/guideline-data/Novice Low/item37.txt
# Created: ../data/guideline-data/Novice Low/item38.txt
# Created: ../data/guideline-data/Novice Low/item39.txt
# Processed: ../data/guideline-data/Novice Low/7.txt
# Created: ../data/guideline-data/Novice Low/item15.txt
# Created: ../data/guideline-data/Novice Low/item16.txt
# Created: ../data/guideline-data/Novice Low/item17.txt
# Created: ../data/guideline-data/Novice Low/item18.txt
# Created: ../data/guideline-data/Novice Low/item19.txt
# Processed: ../data/guideline-data/Novice Low/3.txt
# Created: ../data/guideline-data/Novice Low/item10.txt
# Created: ../data/guideline-data/Novice Low/item11.txt
# Created: ../data/guideline-data/Novice Low/item12.txt
# Created: ../data/guideline-data/Novice Low/item13.txt
# Created: ../data/guideline-data/Novice Low/item14.txt
# Processed: ../data/guideline-data/Novice Low/2.txt
# Created: ../data/guideline-data/Novice Low/item0.txt
# Created: ../data/guideline-data/Novice Low/item1.txt
# Created: ../data/guideline-data/Novice Low/item2.txt
# Created: ../data/guideline-data/Novice Low/item3.txt
# Created: ../data/guideline-data/Novice Low/item4.txt
# Processed: ../data/guideline-data/Novice Low/0.txt
# Created: ../data/guideline-data/Novice Low/item5.txt
# Created: ../data/guideline-data/Novice Low/item6.txt
# Created: ../data/guideline-data/Novice Low/item7.txt
# Created: ../data/guideline-data/Novice Low/item8.txt
# Created: ../data/guideline-data/Novice Low/item9.txt
# Processed: ../data/guideline-data/Novice Low/1.txt
# Created: ../data/guideline-data/Novice Low/item95.txt
# Created: ../data/guideline-data/Novice Low/item96.txt
# Created: ../data/guideline-data/Novice Low/item97.txt
# Created: ../data/guideline-data/Novice Low/item98.txt
# Created: ../data/guideline-data/Novice Low/item99.txt
# Processed: ../data/guideline-data/Novice Low/19.txt
# Created: ../data/guideline-data/Novice Low/item90.txt
# Created: ../data/guideline-data/Novice Low/item91.txt
# Created: ../data/guideline-data/Novice Low/item92.txt
# Created: ../data/guideline-data/Novice Low/item93.txt
# Created: ../data/guideline-data/Novice Low/item94.txt
# Processed: ../data/guideline-data/Novice Low/18.txt
# Created: ../data/guideline-data/Distinguished/item75.txt
# Created: ../data/guideline-data/Distinguished/item76.txt
# Created: ../data/guideline-data/Distinguished/item77.txt
# Created: ../data/guideline-data/Distinguished/item78.txt
# Created: ../data/guideline-data/Distinguished/item79.txt
# Processed: ../data/guideline-data/Distinguished/15.txt
# Created: ../data/guideline-data/Distinguished/item70.txt
# Created: ../data/guideline-data/Distinguished/item71.txt
# Created: ../data/guideline-data/Distinguished/item72.txt
# Created: ../data/guideline-data/Distinguished/item73.txt
# Created: ../data/guideline-data/Distinguished/item74.txt
# Processed: ../data/guideline-data/Distinguished/14.txt
# Created: ../data/guideline-data/Distinguished/item80.txt
# Created: ../data/guideline-data/Distinguished/item81.txt
# Created: ../data/guideline-data/Distinguished/item82.txt
# Created: ../data/guideline-data/Distinguished/item83.txt
# Created: ../data/guideline-data/Distinguished/item84.txt
# Processed: ../data/guideline-data/Distinguished/16.txt
# Created: ../data/guideline-data/Distinguished/item85.txt
# Created: ../data/guideline-data/Distinguished/item86.txt
# Created: ../data/guideline-data/Distinguished/item87.txt
# Created: ../data/guideline-data/Distinguished/item88.txt
# Created: ../data/guideline-data/Distinguished/item89.txt
# Processed: ../data/guideline-data/Distinguished/17.txt
# Created: ../data/guideline-data/Distinguished/item65.txt
# Created: ../data/guideline-data/Distinguished/item66.txt
# Created: ../data/guideline-data/Distinguished/item67.txt
# Created: ../data/guideline-data/Distinguished/item68.txt
# Created: ../data/guideline-data/Distinguished/item69.txt
# Processed: ../data/guideline-data/Distinguished/13.txt
# Created: ../data/guideline-data/Distinguished/item60.txt
# Created: ../data/guideline-data/Distinguished/item61.txt
# Created: ../data/guideline-data/Distinguished/item62.txt
# Created: ../data/guideline-data/Distinguished/item63.txt
# Created: ../data/guideline-data/Distinguished/item64.txt
# Processed: ../data/guideline-data/Distinguished/12.txt
# Created: ../data/guideline-data/Distinguished/item50.txt
# Created: ../data/guideline-data/Distinguished/item51.txt
# Created: ../data/guideline-data/Distinguished/item52.txt
# Created: ../data/guideline-data/Distinguished/item53.txt
# Created: ../data/guideline-data/Distinguished/item54.txt
# Processed: ../data/guideline-data/Distinguished/10.txt
# Created: ../data/guideline-data/Distinguished/item55.txt
# Created: ../data/guideline-data/Distinguished/item56.txt
# Created: ../data/guideline-data/Distinguished/item57.txt
# Created: ../data/guideline-data/Distinguished/item58.txt
# Created: ../data/guideline-data/Distinguished/item59.txt
# Processed: ../data/guideline-data/Distinguished/11.txt
# Created: ../data/guideline-data/Distinguished/item45.txt
# Created: ../data/guideline-data/Distinguished/item46.txt
# Created: ../data/guideline-data/Distinguished/item47.txt
# Created: ../data/guideline-data/Distinguished/item48.txt
# Created: ../data/guideline-data/Distinguished/item49.txt
# Processed: ../data/guideline-data/Distinguished/9.txt
# Created: ../data/guideline-data/Distinguished/item40.txt
# Created: ../data/guideline-data/Distinguished/item41.txt
# Created: ../data/guideline-data/Distinguished/item42.txt
# Created: ../data/guideline-data/Distinguished/item43.txt
# Created: ../data/guideline-data/Distinguished/item44.txt
# Processed: ../data/guideline-data/Distinguished/8.txt
# Created: ../data/guideline-data/Distinguished/item25.txt
# Created: ../data/guideline-data/Distinguished/item26.txt
# Created: ../data/guideline-data/Distinguished/item27.txt
# Created: ../data/guideline-data/Distinguished/item28.txt
# Created: ../data/guideline-data/Distinguished/item29.txt
# Processed: ../data/guideline-data/Distinguished/5.txt
# Created: ../data/guideline-data/Distinguished/item20.txt
# Created: ../data/guideline-data/Distinguished/item21.txt
# Created: ../data/guideline-data/Distinguished/item22.txt
# Created: ../data/guideline-data/Distinguished/item23.txt
# Created: ../data/guideline-data/Distinguished/item24.txt
# Processed: ../data/guideline-data/Distinguished/4.txt
# Created: ../data/guideline-data/Distinguished/item30.txt
# Created: ../data/guideline-data/Distinguished/item31.txt
# Created: ../data/guideline-data/Distinguished/item32.txt
# Created: ../data/guideline-data/Distinguished/item33.txt
# Created: ../data/guideline-data/Distinguished/item34.txt
# Processed: ../data/guideline-data/Distinguished/6.txt
# Created: ../data/guideline-data/Distinguished/item35.txt
# Created: ../data/guideline-data/Distinguished/item36.txt
# Created: ../data/guideline-data/Distinguished/item37.txt
# Created: ../data/guideline-data/Distinguished/item38.txt
# Created: ../data/guideline-data/Distinguished/item39.txt
# Processed: ../data/guideline-data/Distinguished/7.txt
# Created: ../data/guideline-data/Distinguished/item15.txt
# Created: ../data/guideline-data/Distinguished/item16.txt
# Created: ../data/guideline-data/Distinguished/item17.txt
# Created: ../data/guideline-data/Distinguished/item18.txt
# Created: ../data/guideline-data/Distinguished/item19.txt
# Processed: ../data/guideline-data/Distinguished/3.txt
# Created: ../data/guideline-data/Distinguished/item10.txt
# Created: ../data/guideline-data/Distinguished/item11.txt
# Created: ../data/guideline-data/Distinguished/item12.txt
# Created: ../data/guideline-data/Distinguished/item13.txt
# Created: ../data/guideline-data/Distinguished/item14.txt
# Processed: ../data/guideline-data/Distinguished/2.txt
# Created: ../data/guideline-data/Distinguished/item0.txt
# Created: ../data/guideline-data/Distinguished/item1.txt
# Created: ../data/guideline-data/Distinguished/item2.txt
# Created: ../data/guideline-data/Distinguished/item3.txt
# Created: ../data/guideline-data/Distinguished/item4.txt
# Processed: ../data/guideline-data/Distinguished/0.txt
# Created: ../data/guideline-data/Distinguished/item5.txt
# Created: ../data/guideline-data/Distinguished/item6.txt
# Created: ../data/guideline-data/Distinguished/item7.txt
# Created: ../data/guideline-data/Distinguished/item8.txt
# Created: ../data/guideline-data/Distinguished/item9.txt
# Processed: ../data/guideline-data/Distinguished/1.txt
# Created: ../data/guideline-data/Distinguished/item95.txt
# Created: ../data/guideline-data/Distinguished/item96.txt
# Created: ../data/guideline-data/Distinguished/item97.txt
# Created: ../data/guideline-data/Distinguished/item98.txt
# Created: ../data/guideline-data/Distinguished/item99.txt
# Processed: ../data/guideline-data/Distinguished/19.txt
# Created: ../data/guideline-data/Distinguished/item90.txt
# Created: ../data/guideline-data/Distinguished/item91.txt
# Created: ../data/guideline-data/Distinguished/item92.txt
# Created: ../data/guideline-data/Distinguished/item93.txt
# Created: ../data/guideline-data/Distinguished/item94.txt
# Processed: ../data/guideline-data/Distinguished/18.txt
